# %%
import pandas as pd 
import numpy as np

# %%
# Read CSVs
clicks = pd.read_csv('/home/wb1115/VSCode_projects/cdss/cdss_1/cdss_1/click_results/demo_clicks.csv')
hover_events = pd.read_csv('/home/wb1115/VSCode_projects/cdss/cdss_1/cdss_1/hover_results/demo_hover_events.csv')
page_visits = pd.read_csv('/home/wb1115/VSCode_projects/cdss/cdss_1/cdss_1/timing_results/demo_page_visits.csv')

# %% [markdown]
# hover_events

# %%
hover_events
# Out:
#     user_id user_archetype  patient                             component  \
# 0      demo              a        1                  patient_details_age:
# 1      demo              a        1                  patient_details_sex:
# 2      demo              a        1            patient_details_ethnicity:
# 3      demo              a        1             patient_details_imddecil:
# 4      demo              a        1       patient_details_co-morbidities:
# ..      ...            ...      ...                                   ...
# 205    demo              a        3                     vitals_table_SpO2
# 206    demo              a        3                     vitals_table_SpO2
# 207    demo              a        3      vitals_table_Mean Blood Pressure
# 208    demo              a        3      vitals_table_Mean Blood Pressure
# 209    demo              a        3  vitals_table_Systolic Blood Pressure
#
#      hover_duration
# 0             0.033
# 1             0.016
# 2             0.047
# 3             0.133
# 4             0.067
# ..              ...
# 205           0.088
# 206           0.016
# 207           0.037
# 208           0.072
# 209           0.014
#
# [210 rows x 5 columns]

# %%
component_hover_duration = hover_events.groupby('component')['hover_duration'].sum().reset_index()
component_hover_duration = component_hover_duration.sort_values(by='hover_duration', ascending=False).reset_index(drop=True)
component_hover_duration
# Out:
#                                             component  hover_duration
# 0                                        echarts_plot          13.027
# 1                                       feature_image           5.265
# 2                                guidelines_flowchart           4.840
# 3                                      guidelines_pdf           3.047
# 4             vitals_table_NEWS Conscious Level Score           2.130
# 5                                     similar_table_3           2.008
# 6                                   vitals_table_SpO2           1.865
# 7                                     similar_table_2           1.801
# 8                                       patient_table           1.416
# 9   vitals_table_Glasgow Coma Score - verbal response           1.325
# 10                                    similar_table_4           1.252
# 11                                   prediction_alert           1.192
# 12      vitals_table_Glasgow Coma Score – eye opening           0.907
# 13                      similar_table_Similar patient           0.799
# 14                              guidelines_pdf_simple           0.699
# 15                                LLM_positive_points           0.590
# 16              patient_details_antibiotic_treatment:           0.500
# 17                                    similar_table_5           0.500
# 18                    vitals_table_Glasgow Coma Score           0.446
# 19                                    guideline_alert           0.440
# 20                               patient_details_age:           0.435
# 21                      vitals_table_Respiratory Rate           0.415
# 22              vitals_table_Diastolic Blood Pressure           0.367
# 23                                LLM_negative_points           0.367
# 24                                    similar_table_1           0.350
# 25                   vitals_table_Mean Blood Pressure           0.285
# 26                vitals_table_Mean Arterial Pressure           0.283
# 27               vitals_table_Systolic Blood Pressure           0.279
# 28                          patient_details_imddecil:           0.266
# 29   vitals_table_Glasgow Coma Score - motor response           0.201
# 30                    patient_details_co-morbidities:           0.150
# 31                         patient_details_ethnicity:           0.145
# 32                               patient_details_sex:           0.138
# 33                            vitals_table_Heart Rate           0.116
# 34                         patient_details_diagnosis:           0.099
# 35               vitals_table_NEWS Supplemental Oxgen           0.032

# %%
# Grouping components into broader catergories 

# Define a function to categorize the components
def categorize_component(component_str):
    categories = ['vitals_table', 'similar_table', 'patient_details', 'guidelines_pdf', 'LLM']
    for category in categories:
        if category in component_str:
            return category
    return component_str

# Apply the categorization function to create the new column
hover_events['component_categories'] = hover_events['component'].apply(categorize_component)
component_hover_duration = hover_events.groupby('component_categories')['hover_duration'].sum().reset_index()
component_hover_duration = component_hover_duration.sort_values(by='hover_duration', ascending=False).reset_index(drop=True)
component_hover_duration
# Out:
#     component_categories  hover_duration
# 0           echarts_plot          13.027
# 1           vitals_table           8.651
# 2          similar_table           6.710
# 3          feature_image           5.265
# 4   guidelines_flowchart           4.840
# 5         guidelines_pdf           3.746
# 6        patient_details           1.733
# 7          patient_table           1.416
# 8       prediction_alert           1.192
# 9                    LLM           0.957
# 10       guideline_alert           0.440

# %%
# Grouping by patient as well

component_hover_duration = hover_events.groupby(['component_categories', 'patient'])['hover_duration'].sum().reset_index()
component_hover_duration = component_hover_duration.sort_values(by='hover_duration', ascending=False).reset_index(drop=True)
component_hover_duration
# Out:
#     component_categories  patient  hover_duration
# 0           echarts_plot        1          11.666
# 1           vitals_table        1           4.788
# 2          similar_table        1           4.231
# 3           vitals_table        3           3.254
# 4          feature_image        3           3.081
# 5          similar_table        3           2.479
# 6   guidelines_flowchart        1           2.431
# 7   guidelines_flowchart        3           2.409
# 8          feature_image        1           2.184
# 9         guidelines_pdf        1           1.998
# 10        guidelines_pdf        3           1.049
# 11         patient_table        1           0.904
# 12      prediction_alert        1           0.896
# 13          echarts_plot        3           0.843
# 14       patient_details        3           0.821
# 15        guidelines_pdf        2           0.699
# 16       patient_details        2           0.616
# 17          vitals_table        2           0.609
# 18                   LLM        3           0.597
# 19          echarts_plot        2           0.518
# 20         patient_table        3           0.512
# 21                   LLM        1           0.360
# 22       guideline_alert        3           0.308
# 23       patient_details        1           0.296
# 24      prediction_alert        3           0.296
# 25       guideline_alert        1           0.132

# %%
# In future can stack different df from different patricipants, group and then analyze

# %% [markdown]
# page_visits

# %%
# Convert 'entry_time' and 'exit_time' columns to datetime
page_visits['entry_time'] = pd.to_datetime(page_visits['entry_time'])
page_visits['exit_time'] = pd.to_datetime(page_visits['exit_time'])

# Iterate over DataFrame and update exit_time
for index, row in page_visits.iterrows():
    if row['page_name'] == '/record_hover_event/' and index > 0:
        previous_exit_time = page_visits.at[index - 1, 'exit_time']
        if row['exit_time'] > previous_exit_time:
            page_visits.at[index - 1, 'exit_time'] = row['exit_time']

# Drop pages / rows we dont care about
page_visits = page_visits[~page_visits['page_name'].str.contains('favicon|process_user_input|track_link_click|record_hover_event')]
page_visits = page_visits[page_visits['page_name'] != '/']

# Calculate visit duration in seconds
page_visits['visit_duration'] = (page_visits['exit_time'] - page_visits['entry_time']).dt.total_seconds()

# Group by
grouped_page_visits = page_visits.groupby(['page_name'])['visit_duration'].sum().reset_index()
grouped_page_visits = grouped_page_visits.sort_values(by='visit_duration', ascending=False).reset_index(drop=True)
grouped_page_visits
# Out:
#              page_name  visit_duration
# 0             /1_demo/       40.161503
# 1             /3_demo/       24.704385
# 2  /1_demo/prediction/       15.631954
# 3  /3_demo/prediction/       14.009150
# 4       /patients_demo        9.567636
# 5             /2_demo/        8.027680
# 6   /1_demo/guideline/        6.923755
# 7   /3_demo/guideline/        5.403025

# %%
# Grouping page_name into patients

# Define a function to group page_name by patients
def categorize_page_name(component_str):
    categories = [str(element) for element in list(range(13))]
    for category in categories:
        if category in component_str:
            return category
    return component_str

# Apply the categorization function to create the new column
page_visits['page_name_categories'] = page_visits['page_name'].apply(categorize_page_name)
grouped_page_visits = page_visits.groupby('page_name_categories')['visit_duration'].sum().reset_index()
grouped_page_visits = grouped_page_visits.sort_values(by='visit_duration', ascending=False).reset_index(drop=True)
grouped_page_visits
# Out:
#   page_name_categories  visit_duration
# 0                    1       62.717212
# 1                    3       44.116560
# 2       /patients_demo        9.567636
# 3                    2        8.027680

# %%
page_visits
# Out:
#    user_id user_archetype            page_name  \
# 1     demo              a       /patients_demo
# 3     demo              a             /1_demo/
# 6     demo              a  /1_demo/prediction/
# 8     demo              a             /1_demo/
# 11    demo              a   /1_demo/guideline/
# 15    demo              a             /1_demo/
# 18    demo              a       /patients_demo
# 19    demo              a             /2_demo/
# 24    demo              a       /patients_demo
# 25    demo              a             /3_demo/
# 28    demo              a  /3_demo/prediction/
# 30    demo              a             /3_demo/
# 33    demo              a   /3_demo/guideline/
# 37    demo              a             /3_demo/
# 40    demo              a       /patients_demo
#
#                          entry_time                        exit_time  \
# 1  2024-03-13 15:52:43.810713+00:00 2024-03-13 15:52:43.852561+00:00
# 3  2024-03-13 15:52:45.672470+00:00 2024-03-13 15:53:07.986090+00:00
# 6  2024-03-13 15:53:08.014844+00:00 2024-03-13 15:53:23.646798+00:00
# 8  2024-03-13 15:53:23.664754+00:00 2024-03-13 15:53:30.087907+00:00
# 11 2024-03-13 15:53:30.108387+00:00 2024-03-13 15:53:37.032142+00:00
# 15 2024-03-13 15:53:45.065539+00:00 2024-03-13 15:53:56.490269+00:00
# 18 2024-03-13 15:53:56.514283+00:00 2024-03-13 15:53:58.959039+00:00
# 19 2024-03-13 15:53:58.969356+00:00 2024-03-13 15:54:06.997036+00:00
# 24 2024-03-13 15:54:16.099222+00:00 2024-03-13 15:54:20.218725+00:00
# 25 2024-03-13 15:54:20.224338+00:00 2024-03-13 15:54:34.378743+00:00
# 28 2024-03-13 15:54:34.401451+00:00 2024-03-13 15:54:48.410601+00:00
# 30 2024-03-13 15:54:48.418403+00:00 2024-03-13 15:54:51.717999+00:00
# 33 2024-03-13 15:54:51.743895+00:00 2024-03-13 15:54:57.146920+00:00
# 37 2024-03-13 15:55:02.485486+00:00 2024-03-13 15:55:09.735870+00:00
# 40 2024-03-13 15:55:09.758647+00:00 2024-03-13 15:55:12.720176+00:00
#
#     visit_duration page_name_categories
# 1         0.041848       /patients_demo
# 3        22.313620                    1
# 6        15.631954                    1
# 8         6.423153                    1
# 11        6.923755                    1
# 15       11.424730                    1
# 18        2.444756       /patients_demo
# 19        8.027680                    2
# 24        4.119503       /patients_demo
# 25       14.154405                    3
# 28       14.009150                    3
# 30        3.299596                    3
# 33        5.403025                    3
# 37        7.250384                    3
# 40        2.961529       /patients_demo

# %% [markdown]
# clicks

# %%
clicks
# Out:
#   user_id user_archetype  patient            link_clicks  \
# 0    demo              a        1  predictiondetailsLink
# 1    demo              a        1   guidelinedetailsLink
# 2    demo              a        1         guidelinesLink
# 3    demo              a        2  guidelinesLink_simple
# 4    demo              a        3  predictiondetailsLink
# 5    demo              a        3   guidelinedetailsLink
# 6    demo              a        3         guidelinesLink
#
#                           timestamp
# 0  2024-03-13 15:53:07.976616+00:00
# 1  2024-03-13 15:53:30.080327+00:00
# 2  2024-03-13 15:53:37.017701+00:00
# 3  2024-03-13 15:54:06.985623+00:00
# 4  2024-03-13 15:54:34.368593+00:00
# 5  2024-03-13 15:54:51.712688+00:00
# 6  2024-03-13 15:54:57.139433+00:00

# %%
clicks['link_clicks'].value_counts()
# Out:
# link_clicks
# predictiondetailsLink    2
# guidelinedetailsLink     2
# guidelinesLink           2
# guidelinesLink_simple    1
# Name: count, dtype: int64

# %%
clicks.groupby('patient')['link_clicks'].value_counts()
# Out:
# patient  link_clicks
# 1        guidelinedetailsLink     1
#          guidelinesLink           1
#          predictiondetailsLink    1
# 2        guidelinesLink_simple    1
# 3        guidelinedetailsLink     1
#          guidelinesLink           1
#          predictiondetailsLink    1
# Name: count, dtype: int64

# %%
# Define a function to group page_name by patients
def categorize_link_clicks(component_str):
    categories = ['guidelinesLink']
    for category in categories:
        if category in component_str:
            return category
    return component_str

# Apply the categorization function to create the new column
clicks['link_clicks_categories'] = clicks['link_clicks'].apply(categorize_link_clicks)
clicks['link_clicks_categories'].value_counts()
# Out:
# link_clicks_categories
# guidelinesLink           3
# predictiondetailsLink    2
# guidelinedetailsLink     2
# Name: count, dtype: int64

# %%
# In future add column to df based on user_archetype and patient 
# to determine if they saw 'soc' or 'cdss'
# can then groubby that for interesting results!
